# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['mel']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the ResNet50 model function
def build_resnet50_model(input_shape, num_classes):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_resnet50_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: mel
# Epoch 1/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.6609 - accuracy: 0.6190 - val_loss: 0.6588 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 19s 321ms/step - loss: 0.6617 - accuracy: 0.6254 - val_loss: 0.6579 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 20s 332ms/step - loss: 0.6615 - accuracy: 0.6254 - val_loss: 0.6580 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 20s 330ms/step - loss: 0.6613 - accuracy: 0.6254 - val_loss: 0.6593 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 20s 337ms/step - loss: 0.6595 - accuracy: 0.6254 - val_loss: 0.6566 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 20s 328ms/step - loss: 0.6610 - accuracy: 0.6254 - val_loss: 0.6567 - val_accuracy: 0.6286
# Epoch 7/50
# 60/60 [==============================] - 20s 339ms/step - loss: 0.6588 - accuracy: 0.6254 - val_loss: 0.6598 - val_accuracy: 0.6286
# Epoch 8/50
# 60/60 [==============================] - 40s 671ms/step - loss: 0.6598 - accuracy: 0.6254 - val_loss: 0.6583 - val_accuracy: 0.6286
# Epoch 9/50
# 60/60 [==============================] - 39s 647ms/step - loss: 0.6577 - accuracy: 0.6254 - val_loss: 0.6624 - val_accuracy: 0.6286
# Epoch 10/50
# 60/60 [==============================] - 39s 655ms/step - loss: 0.6613 - accuracy: 0.6254 - val_loss: 0.6563 - val_accuracy: 0.6286
# Epoch 11/50
# 60/60 [==============================] - 38s 641ms/step - loss: 0.6579 - accuracy: 0.6254 - val_loss: 0.6563 - val_accuracy: 0.6286
# Epoch 12/50
# 60/60 [==============================] - 39s 645ms/step - loss: 0.6579 - accuracy: 0.6254 - val_loss: 0.6560 - val_accuracy: 0.6286
# Epoch 13/50
# 60/60 [==============================] - 39s 643ms/step - loss: 0.6587 - accuracy: 0.6254 - val_loss: 0.6560 - val_accuracy: 0.6286
# Epoch 14/50
\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fold 2 Results: Accuracy=62.86%, F1=0.49, Precision=0.40, Recall=0.63, Specificity=1.00, Kappa=0.00, ROC AUC=0.48
# Epoch 1/50
# 60/60 [==============================] - 42s 699ms/step - loss: 0.6578 - accuracy: 0.6254 - val_loss: 0.6562 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 38s 637ms/step - loss: 0.6568 - accuracy: 0.6254 - val_loss: 0.6599 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 38s 637ms/step - loss: 0.6586 - accuracy: 0.6254 - val_loss: 0.6568 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 39s 649ms/step - loss: 0.6589 - accuracy: 0.6254 - val_loss: 0.6560 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 39s 643ms/step - loss: 0.6556 - accuracy: 0.6254 - val_loss: 0.6576 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 38s 639ms/step - loss: 0.6572 - accuracy: 0.6254 - val_loss: 0.6566 - val_accuracy: 0.6286
# Epoch 7/50
# 60/60 [==============================] - 38s 639ms/step - loss: 0.6558 - accuracy: 0.6254 - val_loss: 0.6561 - val_accuracy: 0.6286
# Epoch 8/50
# 60/60 [==============================] - 39s 643ms/step - loss: 0.6551 - accuracy: 0.6254 - val_loss: 0.6600 - val_accuracy: 0.6286
# Epoch 9/50
# 60/60 [==============================] - 38s 632ms/step - loss: 0.6546 - accuracy: 0.6254 - val_loss: 0.6581 - val_accuracy: 0.6286
# C:\ProgramData\Anaconda3\envs\Tremor_tf\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fold 3 Results: Accuracy=62.86%, F1=0.49, Precision=0.40, Recall=0.63, Specificity=1.00, Kappa=0.00, ROC AUC=0.51
# Epoch 1/50
# 60/60 [==============================] - 42s 697ms/step - loss: 0.6560 - accuracy: 0.6254 - val_loss: 0.6596 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 39s 651ms/step - loss: 0.6569 - accuracy: 0.6254 - val_loss: 0.6597 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 38s 641ms/step - loss: 0.6534 - accuracy: 0.6254 - val_loss: 0.6607 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 38s 637ms/step - loss: 0.6545 - accuracy: 0.6254 - val_loss: 0.6603 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 38s 633ms/step - loss: 0.6542 - accuracy: 0.6254 - val_loss: 0.6624 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 38s 636ms/step - loss: 0.6541 - accuracy: 0.6254 - val_loss: 0.6602 - val_accuracy: 0.6286
# C:\ProgramData\Anaconda3\envs\Tremor_tf\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fold 4 Results: Accuracy=62.86%, F1=0.49, Precision=0.40, Recall=0.63, Specificity=1.00, Kappa=0.00, ROC AUC=0.56
# Epoch 1/50
# 60/60 [==============================] - 43s 710ms/step - loss: 0.6565 - accuracy: 0.6254 - val_loss: 0.6560 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 39s 651ms/step - loss: 0.6568 - accuracy: 0.6254 - val_loss: 0.6572 - val_accuracy: 0.6286
# Epoch 3/50
\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Fold 10 Results: Accuracy=61.90%, F1=0.47, Precision=0.38, Recall=0.62, Specificity=1.00, Kappa=0.00, ROC AUC=0.72
# Mean and Std Dev of Performance Metrics for Spectrogram mel:
# Fold                   5.500000
# Accuracy              62.571429
# F1 Score               0.481666
# Precision              0.391537
# Recall                 0.625714
# Specificity            1.000000
# Kappa                  0.000000
# ROC AUC                0.587792
# Training Time (s)    476.448366
# Testing Time (s)       6.922145
# dtype: float64
# Fold                   3.027650
# Accuracy               0.460044
# F1 Score               0.005711
# Precision              0.005740
# Recall                 0.004600
# Specificity            0.000000
# Kappa                  0.000000
# ROC AUC                0.070657
# Training Time (s)    196.205826
# Testing Time (s)       0.629973
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['mel']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the VGG19 model function
def build_vgg19_model(input_shape, num_classes):
    base_model = tf.keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_vgg19_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: mel
# Epoch 1/50
# 60/60 [==============================] - 116s 2s/step - loss: 0.6608 - accuracy: 0.6212 - val_loss: 0.6559 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 117s 2s/step - loss: 0.6528 - accuracy: 0.6296 - val_loss: 0.6489 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.6405 - accuracy: 0.6254 - val_loss: 0.6437 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 118s 2s/step - loss: 0.6335 - accuracy: 0.6339 - val_loss: 0.6384 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.6267 - accuracy: 0.6339 - val_loss: 0.6315 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 114s 2s/step - loss: 0.6202 - accuracy: 0.6349 - val_loss: 0.6275 - val_accuracy: 0.6381
# Epoch 7/50
# 60/60 [==============================] - 118s 2s/step - loss: 0.6124 - accuracy: 0.6593 - val_loss: 0.6217 - val_accuracy: 0.6286
# Epoch 8/50
# Epoch 7/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.4692 - accuracy: 0.7862 - val_loss: 0.4535 - val_accuracy: 0.7905
# Epoch 8/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.4559 - accuracy: 0.8011 - val_loss: 0.4570 - val_accuracy: 0.7905
# Epoch 9/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.4543 - accuracy: 0.8074 - val_loss: 0.4559 - val_accuracy: 0.8000
# Epoch 10/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.4538 - accuracy: 0.7989 - val_loss: 0.4691 - val_accuracy: 0.8286
# Epoch 11/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.4501 - accuracy: 0.8074 - val_loss: 0.4559 - val_accuracy: 0.8000
# Epoch 12/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.4524 - accuracy: 0.8032 - val_loss: 0.4545 - val_accuracy: 0.8000
# Fold 3 Results: Accuracy=79.05%, F1=0.79, Precision=0.79, Recall=0.79, Specificity=0.85, Kappa=0.55, ROC AUC=0.87
# Epoch 1/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.4566 - accuracy: 0.8021 - val_loss: 0.4601 - val_accuracy: 0.7714
# Epoch 2/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.4605 - accuracy: 0.7873 - val_loss: 0.4591 - val_accuracy: 0.7810
# Epoch 3/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.4508 - accuracy: 0.8063 - val_loss: 0.4608 - val_accuracy: 0.7905
# Epoch 4/50
# 60/60 [==============================] - 118s 2s/step - loss: 0.4475 - accuracy: 0.8074 - val_loss: 0.4587 - val_accuracy: 0.7905
# Epoch 5/50
# 60/60 [==============================] - 125s 2s/step - loss: 0.4493 - accuracy: 0.8085 - val_loss: 0.4640 - val_accuracy: 0.7333
# Epoch 6/50
# 60/60 [==============================] - 118s 2s/step - loss: 0.4463 - accuracy: 0.8042 - val_loss: 0.4667 - val_accuracy: 0.7429
# Epoch 7/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.4515 - accuracy: 0.8063 - val_loss: 0.4613 - val_accuracy: 0.7810
# Epoch 8/50
# 60/60 [==============================] - 123s 2s/step - loss: 0.4414 - accuracy: 0.8127 - val_loss: 0.4604 - val_accuracy: 0.7905
# Epoch 9/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.4390 - accuracy: 0.8116 - val_loss: 0.4652 - val_accuracy: 0.7429
# Fold 4 Results: Accuracy=79.05%, F1=0.79, Precision=0.79, Recall=0.79, Specificity=0.86, Kappa=0.54, ROC AUC=0.87
# Epoch 1/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.4586 - accuracy: 0.7905 - val_loss: 0.3933 - val_accuracy: 0.8571
# Epoch 2/50
# 60/60 [==============================] - 129s 2s/step - loss: 0.4525 - accuracy: 0.7937 - val_loss: 0.4089 - val_accuracy: 0.8286
# Epoch 3/50
# 60/60 [==============================] - 132s 2s/step - loss: 0.4550 - accuracy: 0.8127 - val_loss: 0.3742 - val_accuracy: 0.8857
# 60/60 [==============================] - 129s 2s/step - loss: 0.3918 - accuracy: 0.8349 - val_loss: 0.4412 - val_accuracy: 0.7810
# Epoch 15/50
# 60/60 [==============================] - 125s 2s/step - loss: 0.4042 - accuracy: 0.8434 - val_loss: 0.4257 - val_accuracy: 0.8286
# Epoch 16/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.3900 - accuracy: 0.8434 - val_loss: 0.4256 - val_accuracy: 0.8286
# Fold 8 Results: Accuracy=82.86%, F1=0.83, Precision=0.83, Recall=0.83, Specificity=0.91, Kappa=0.63, ROC AUC=0.89
# Epoch 1/50
# 60/60 [==============================] - 127s 2s/step - loss: 0.4078 - accuracy: 0.8265 - val_loss: 0.3659 - val_accuracy: 0.8667
# Epoch 2/50
# 60/60 [==============================] - 132s 2s/step - loss: 0.4028 - accuracy: 0.8222 - val_loss: 0.3836 - val_accuracy: 0.8762
# Epoch 3/50
# 60/60 [==============================] - 127s 2s/step - loss: 0.4040 - accuracy: 0.8370 - val_loss: 0.3674 - val_accuracy: 0.8857
# Epoch 4/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.3966 - accuracy: 0.8381 - val_loss: 0.3691 - val_accuracy: 0.8857
# Epoch 5/50
# 60/60 [==============================] - 129s 2s/step - loss: 0.3942 - accuracy: 0.8317 - val_loss: 0.3695 - val_accuracy: 0.8762
# Epoch 6/50
# 60/60 [==============================] - 129s 2s/step - loss: 0.3958 - accuracy: 0.8328 - val_loss: 0.3673 - val_accuracy: 0.8952
# Fold 9 Results: Accuracy=86.67%, F1=0.87, Precision=0.87, Recall=0.87, Specificity=0.91, Kappa=0.71, ROC AUC=0.94
# Epoch 1/50
# 60/60 [==============================] - 130s 2s/step - loss: 0.3991 - accuracy: 0.8392 - val_loss: 0.4205 - val_accuracy: 0.8000
# Epoch 2/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.3919 - accuracy: 0.8392 - val_loss: 0.4209 - val_accuracy: 0.8000
# Epoch 3/50
# 60/60 [==============================] - 122s 2s/step - loss: 0.3953 - accuracy: 0.8476 - val_loss: 0.4319 - val_accuracy: 0.8000
# Epoch 4/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.3887 - accuracy: 0.8455 - val_loss: 0.4187 - val_accuracy: 0.8190
# Epoch 5/50
# 60/60 [==============================] - 133s 2s/step - loss: 0.3846 - accuracy: 0.8444 - val_loss: 0.4198 - val_accuracy: 0.8190
# Epoch 6/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.3829 - accuracy: 0.8423 - val_loss: 0.4326 - val_accuracy: 0.7810
# Epoch 7/50
# 60/60 [==============================] - 127s 2s/step - loss: 0.3970 - accuracy: 0.8381 - val_loss: 0.4426 - val_accuracy: 0.7905
# Epoch 8/50
# 60/60 [==============================] - 121s 2s/step - loss: 0.3809 - accuracy: 0.8476 - val_loss: 0.4253 - val_accuracy: 0.7905
# Epoch 9/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.3805 - accuracy: 0.8497 - val_loss: 0.4197 - val_accuracy: 0.8095
# Fold 10 Results: Accuracy=81.90%, F1=0.82, Precision=0.82, Recall=0.82, Specificity=0.89, Kappa=0.61, ROC AUC=0.88
# Mean and Std Dev of Performance Metrics for Spectrogram mel:
# Fold                    5.500000
# Accuracy               81.047619
# F1 Score                0.806233
# Precision               0.808926
# Recall                  0.810476
# Specificity             0.893497
# Kappa                   0.581334
# ROC AUC                 0.872241
# Training Time (s)    1758.834363
# Testing Time (s)       13.336088
# dtype: float64
# Fold                    3.027650
# Accuracy                4.293350
# F1 Score                0.046022
# Precision               0.044176
# Recall                  0.042934
# Specificity             0.025579
# Kappa                   0.101555
# ROC AUC                 0.059044
# Training Time (s)    1453.571435
# Testing Time (s)        0.971300
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['mel']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the MobileNetV2 model function
def build_mobilenetv2_model(input_shape, num_classes):
    base_model = tf.keras.applications.MobileNetV2(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_mobilenetv2_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: mel
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9412608/9406464 [==============================] - 1s 0us/step
# Epoch 1/50
# 60/60 [==============================] - 5227s 87s/step - loss: 0.6414 - accuracy: 0.6540 - val_loss: 0.6094 - val_accuracy: 0.7048
# Epoch 2/50
# 60/60 [==============================] - 15s 243ms/step - loss: 0.5575 - accuracy: 0.7249 - val_loss: 0.5920 - val_accuracy: 0.7333
# Epoch 3/50
# 60/60 [==============================] - 15s 249ms/step - loss: 0.5081 - accuracy: 0.7725 - val_loss: 0.5865 - val_accuracy: 0.7714
# Epoch 4/50
# 60/60 [==============================] - 15s 245ms/step - loss: 0.4736 - accuracy: 0.8063 - val_loss: 0.5752 - val_accuracy: 0.7524
# Epoch 5/50
# 60/60 [==============================] - 15s 253ms/step - loss: 0.4483 - accuracy: 0.8159 - val_loss: 0.5692 - val_accuracy: 0.7524
# Epoch 6/50
# 60/60 [==============================] - 15s 244ms/step - loss: 0.4273 - accuracy: 0.8307 - val_loss: 0.5904 - val_accuracy: 0.7429
# Epoch 7/50
# 60/60 [==============================] - 15s 245ms/step - loss: 0.4053 - accuracy: 0.8381 - val_loss: 0.5699 - val_accuracy: 0.7619
# Epoch 8/50
# 60/60 [==============================] - 15s 251ms/step - loss: 0.3829 - accuracy: 0.8370 - val_loss: 0.5742 - val_accuracy: 0.7524
# Epoch 9/50
# Epoch 5/50
# 60/60 [==============================] - 19s 310ms/step - loss: 0.0993 - accuracy: 0.9862 - val_loss: 0.1618 - val_accuracy: 0.9429
# Epoch 6/50
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0913 - accuracy: 0.9905 - val_loss: 0.1659 - val_accuracy: 0.9333
# Fold 7 Results: Accuracy=97.14%, F1=0.97, Precision=0.97, Recall=0.97, Specificity=0.98, Kappa=0.94, ROC AUC=1.00
# Epoch 1/50
# 60/60 [==============================] - 22s 360ms/step - loss: 0.1451 - accuracy: 0.9608 - val_loss: 0.1443 - val_accuracy: 0.9524
# Epoch 2/50
# 60/60 [==============================] - 19s 315ms/step - loss: 0.1354 - accuracy: 0.9683 - val_loss: 0.1362 - val_accuracy: 0.9714
# Epoch 3/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.1204 - accuracy: 0.9757 - val_loss: 0.1234 - val_accuracy: 0.9714
# Epoch 4/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.1042 - accuracy: 0.9831 - val_loss: 0.1248 - val_accuracy: 0.9714
# Epoch 5/50
# 60/60 [==============================] - 18s 306ms/step - loss: 0.0957 - accuracy: 0.9915 - val_loss: 0.1332 - val_accuracy: 0.9619
# Epoch 6/50
# 60/60 [==============================] - 18s 305ms/step - loss: 0.1086 - accuracy: 0.9788 - val_loss: 0.1306 - val_accuracy: 0.9619
# Epoch 7/50
# 60/60 [==============================] - 18s 307ms/step - loss: 0.0912 - accuracy: 0.9926 - val_loss: 0.1260 - val_accuracy: 0.9714
# Epoch 8/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0759 - accuracy: 0.9958 - val_loss: 0.1279 - val_accuracy: 0.9714
# Fold 8 Results: Accuracy=97.14%, F1=0.97, Precision=0.97, Recall=0.97, Specificity=1.00, Kappa=0.94, ROC AUC=1.00
# Epoch 1/50
# 60/60 [==============================] - 22s 362ms/step - loss: 0.1147 - accuracy: 0.9810 - val_loss: 0.0949 - val_accuracy: 1.0000
# Epoch 2/50
# 60/60 [==============================] - 18s 307ms/step - loss: 0.1012 - accuracy: 0.9884 - val_loss: 0.1098 - val_accuracy: 0.9714
# Epoch 3/50
# 60/60 [==============================] - 18s 302ms/step - loss: 0.0883 - accuracy: 0.9926 - val_loss: 0.0972 - val_accuracy: 0.9905
# Epoch 4/50
# 60/60 [==============================] - 19s 313ms/step - loss: 0.0778 - accuracy: 0.9937 - val_loss: 0.0993 - val_accuracy: 0.9905
# Epoch 5/50
# 60/60 [==============================] - 19s 313ms/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 0.9714
# Epoch 6/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0646 - accuracy: 0.9989 - val_loss: 0.1103 - val_accuracy: 0.9714
# Fold 9 Results: Accuracy=100.00%, F1=1.00, Precision=1.00, Recall=1.00, Specificity=1.00, Kappa=1.00, ROC AUC=1.00
# Epoch 1/50
# 60/60 [==============================] - 21s 358ms/step - loss: 0.1049 - accuracy: 0.9841 - val_loss: 0.1664 - val_accuracy: 0.9429
# Epoch 2/50
# 60/60 [==============================] - 19s 317ms/step - loss: 0.0969 - accuracy: 0.9894 - val_loss: 0.1161 - val_accuracy: 0.9810
# Epoch 3/50
# 60/60 [==============================] - 19s 314ms/step - loss: 0.0766 - accuracy: 0.9968 - val_loss: 0.1133 - val_accuracy: 0.9714
# Epoch 4/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0722 - accuracy: 0.9968 - val_loss: 0.1253 - val_accuracy: 0.9714
# Epoch 5/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0636 - accuracy: 0.9968 - val_loss: 0.1172 - val_accuracy: 0.9810
# Epoch 6/50
# 60/60 [==============================] - 19s 310ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9619
# Epoch 7/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9524
# Epoch 8/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0459 - accuracy: 0.9989 - val_loss: 0.1192 - val_accuracy: 0.9429
# Fold 10 Results: Accuracy=97.14%, F1=0.97, Precision=0.97, Recall=0.97, Specificity=0.95, Kappa=0.94, ROC AUC=1.00
# Mean and Std Dev of Performance Metrics for Spectrogram mel:
# Fold                   5.500000
# Accuracy              92.666667
# F1 Score               0.924389
# Precision              0.927298
# Recall                 0.926667
# Specificity            0.966597
# Kappa                  0.836267
# ROC AUC                0.946933
# Training Time (s)    684.472064
# Testing Time (s)       4.202873
# dtype: float64
# Fold                    3.027650
# Accuracy                8.363739
# F1 Score                0.087986
# Precision               0.083615
# Recall                  0.083637
# Specificity             0.036306
# Kappa                   0.191717
# ROC AUC                 0.094733
# Training Time (s)    1652.259559
# Testing Time (s)        0.473493
# dtype: float64

# %% [markdown]
# #Type 2 MFCC

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['mfcc']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the MobileNetV2 model function
def build_mobilenetv2_model(input_shape, num_classes):
    base_model = tf.keras.applications.MobileNetV2(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_mobilenetv2_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: mfcc
# Epoch 1/50
# 60/60 [==============================] - 19s 310ms/step - loss: 0.6354 - accuracy: 0.6593 - val_loss: 0.6509 - val_accuracy: 0.6571
# Epoch 2/50
# 60/60 [==============================] - 16s 267ms/step - loss: 0.5952 - accuracy: 0.6910 - val_loss: 0.6401 - val_accuracy: 0.6381
# Epoch 3/50
# 60/60 [==============================] - 16s 269ms/step - loss: 0.5704 - accuracy: 0.7079 - val_loss: 0.6401 - val_accuracy: 0.6571
# Epoch 4/50
# 60/60 [==============================] - 17s 281ms/step - loss: 0.5503 - accuracy: 0.7217 - val_loss: 0.6390 - val_accuracy: 0.6571
# Epoch 5/50
# 60/60 [==============================] - 14s 228ms/step - loss: 0.5363 - accuracy: 0.7333 - val_loss: 0.6441 - val_accuracy: 0.6381
# Epoch 6/50
# 60/60 [==============================] - 17s 282ms/step - loss: 0.5253 - accuracy: 0.7460 - val_loss: 0.6534 - val_accuracy: 0.6571
# Epoch 7/50
# 60/60 [==============================] - 16s 273ms/step - loss: 0.5098 - accuracy: 0.7630 - val_loss: 0.6456 - val_accuracy: 0.6095
# Epoch 8/50
# 60/60 [==============================] - 16s 262ms/step - loss: 0.5040 - accuracy: 0.7672 - val_loss: 0.6507 - val_accuracy: 0.6762
# Epoch 9/50
# 60/60 [==============================] - 16s 263ms/step - loss: 0.4971 - accuracy: 0.7566 - val_loss: 0.6651 - val_accuracy: 0.6952
# Fold 1 Results: Accuracy=65.71%, F1=0.64, Precision=0.64, Recall=0.66, Specificity=0.83, Kappa=0.21, ROC AUC=0.63
# Epoch 1/50
# 60/60 [==============================] - 19s 312ms/step - loss: 0.5477 - accuracy: 0.7333 - val_loss: 0.5551 - val_accuracy: 0.7238
# Epoch 2/50
# 60/60 [==============================] - 15s 249ms/step - loss: 0.5407 - accuracy: 0.7302 - val_loss: 0.5731 - val_accuracy: 0.6952
# Epoch 3/50
# 60/60 [==============================] - 15s 247ms/step - loss: 0.5211 - accuracy: 0.7460 - val_loss: 0.5622 - val_accuracy: 0.6952
# Epoch 4/50
# 60/60 [==============================] - 15s 258ms/step - loss: 0.5083 - accuracy: 0.7598 - val_loss: 0.5510 - val_accuracy: 0.7238
# Epoch 5/50
# 60/60 [==============================] - 19s 309ms/step - loss: 0.5077 - accuracy: 0.7556 - val_loss: 0.5585 - val_accuracy: 0.7143
# Epoch 6/50
# 60/60 [==============================] - 16s 271ms/step - loss: 0.5041 - accuracy: 0.7566 - val_loss: 0.5430 - val_accuracy: 0.7524
# Epoch 7/50
# 60/60 [==============================] - 16s 259ms/step - loss: 0.4889 - accuracy: 0.7683 - val_loss: 0.5572 - val_accuracy: 0.7238
# Epoch 8/50
# 60/60 [==============================] - 15s 257ms/step - loss: 0.4824 - accuracy: 0.7608 - val_loss: 0.5423 - val_accuracy: 0.7333
# Epoch 9/50
# 60/60 [==============================] - 16s 262ms/step - loss: 0.4669 - accuracy: 0.7968 - val_loss: 0.5382 - val_accuracy: 0.7429
# Epoch 10/50
# 60/60 [==============================] - 15s 251ms/step - loss: 0.4566 - accuracy: 0.7979 - val_loss: 0.5371 - val_accuracy: 0.7619
# Epoch 11/50
# Fold 6 Results: Accuracy=79.05%, F1=0.78, Precision=0.79, Recall=0.79, Specificity=0.91, Kappa=0.53, ROC AUC=0.91
# Epoch 1/50
# 60/60 [==============================] - 20s 341ms/step - loss: 0.3946 - accuracy: 0.8222 - val_loss: 0.3705 - val_accuracy: 0.8571
# Epoch 2/50
# 60/60 [==============================] - 15s 258ms/step - loss: 0.3767 - accuracy: 0.8402 - val_loss: 0.3775 - val_accuracy: 0.8381
# Epoch 3/50
# 60/60 [==============================] - 16s 270ms/step - loss: 0.3669 - accuracy: 0.8635 - val_loss: 0.4251 - val_accuracy: 0.7810
# Epoch 4/50
# 60/60 [==============================] - 18s 293ms/step - loss: 0.3612 - accuracy: 0.8508 - val_loss: 0.4490 - val_accuracy: 0.7714
# Epoch 5/50
# 60/60 [==============================] - 18s 292ms/step - loss: 0.3519 - accuracy: 0.8677 - val_loss: 0.3825 - val_accuracy: 0.8190
# Epoch 6/50
# 60/60 [==============================] - 16s 259ms/step - loss: 0.3392 - accuracy: 0.8751 - val_loss: 0.3824 - val_accuracy: 0.8190
# Fold 7 Results: Accuracy=85.71%, F1=0.85, Precision=0.87, Recall=0.86, Specificity=0.97, Kappa=0.68, ROC AUC=0.93
# Epoch 1/50
# 60/60 [==============================] - 20s 332ms/step - loss: 0.3874 - accuracy: 0.8265 - val_loss: 0.3528 - val_accuracy: 0.8667
# Epoch 2/50
# 60/60 [==============================] - 16s 264ms/step - loss: 0.3652 - accuracy: 0.8540 - val_loss: 0.3600 - val_accuracy: 0.8476
# Epoch 3/50
# 60/60 [==============================] - 16s 262ms/step - loss: 0.3654 - accuracy: 0.8455 - val_loss: 0.3579 - val_accuracy: 0.8667
# Epoch 4/50
# 60/60 [==============================] - 15s 256ms/step - loss: 0.3507 - accuracy: 0.8646 - val_loss: 0.3598 - val_accuracy: 0.8762
# Epoch 5/50
# 60/60 [==============================] - 16s 261ms/step - loss: 0.3355 - accuracy: 0.8762 - val_loss: 0.3631 - val_accuracy: 0.8476
# Epoch 6/50
# 60/60 [==============================] - 16s 265ms/step - loss: 0.3263 - accuracy: 0.8804 - val_loss: 0.3641 - val_accuracy: 0.8571
# Fold 8 Results: Accuracy=86.67%, F1=0.86, Precision=0.88, Recall=0.87, Specificity=0.98, Kappa=0.70, ROC AUC=0.94
# Epoch 1/50
# 60/60 [==============================] - 19s 323ms/step - loss: 0.3828 - accuracy: 0.8455 - val_loss: 0.3406 - val_accuracy: 0.8381
# Epoch 2/50
# 60/60 [==============================] - 16s 260ms/step - loss: 0.3603 - accuracy: 0.8444 - val_loss: 0.3217 - val_accuracy: 0.8762
# Epoch 3/50
# 60/60 [==============================] - 16s 265ms/step - loss: 0.3497 - accuracy: 0.8550 - val_loss: 0.3168 - val_accuracy: 0.8762
# Epoch 4/50
# 60/60 [==============================] - 16s 267ms/step - loss: 0.3463 - accuracy: 0.8656 - val_loss: 0.3205 - val_accuracy: 0.8762
# Epoch 5/50
# 60/60 [==============================] - 16s 264ms/step - loss: 0.3421 - accuracy: 0.8614 - val_loss: 0.3269 - val_accuracy: 0.8667
# Epoch 6/50
# 60/60 [==============================] - 15s 257ms/step - loss: 0.3278 - accuracy: 0.8688 - val_loss: 0.3302 - val_accuracy: 0.8667
# Epoch 7/50
# 60/60 [==============================] - 16s 261ms/step - loss: 0.3178 - accuracy: 0.8836 - val_loss: 0.3454 - val_accuracy: 0.8381
# Epoch 8/50
# 60/60 [==============================] - 15s 252ms/step - loss: 0.3099 - accuracy: 0.8857 - val_loss: 0.3387 - val_accuracy: 0.8381
# Fold 9 Results: Accuracy=87.62%, F1=0.87, Precision=0.88, Recall=0.88, Specificity=0.95, Kappa=0.73, ROC AUC=0.95
# Epoch 1/50
# 60/60 [==============================] - 20s 329ms/step - loss: 0.3444 - accuracy: 0.8698 - val_loss: 0.3402 - val_accuracy: 0.8571
# Epoch 2/50
# 60/60 [==============================] - 16s 264ms/step - loss: 0.3337 - accuracy: 0.8709 - val_loss: 0.3483 - val_accuracy: 0.8381
# Epoch 3/50
# 60/60 [==============================] - 17s 276ms/step - loss: 0.3240 - accuracy: 0.8720 - val_loss: 0.3556 - val_accuracy: 0.8381
# Epoch 4/50
# 60/60 [==============================] - 16s 267ms/step - loss: 0.3233 - accuracy: 0.8783 - val_loss: 0.3592 - val_accuracy: 0.8381
# Epoch 5/50
# 60/60 [==============================] - 16s 261ms/step - loss: 0.3076 - accuracy: 0.8794 - val_loss: 0.3491 - val_accuracy: 0.8476
# Epoch 6/50
# 60/60 [==============================] - 16s 271ms/step - loss: 0.3025 - accuracy: 0.8899 - val_loss: 0.3525 - val_accuracy: 0.8762
# Fold 10 Results: Accuracy=85.71%, F1=0.85, Precision=0.87, Recall=0.86, Specificity=0.97, Kappa=0.68, ROC AUC=0.95
# Mean and Std Dev of Performance Metrics for Spectrogram mfcc:
# Fold                   5.500000
# Accuracy              80.952381
# F1 Score               0.802937
# Precision              0.810959
# Recall                 0.809524
# Specificity            0.915012
# Kappa                  0.572982
# ROC AUC                0.871300
# Training Time (s)    145.555209
# Testing Time (s)       4.739163
# dtype: float64
# Fold                  3.027650
# Accuracy              6.853026
# F1 Score              0.072765
# Precision             0.076664
# Recall                0.068530
# Specificity           0.055279
# Kappa                 0.159257
# ROC AUC               0.099608
# Training Time (s)    54.442408
# Testing Time (s)      0.423353
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['mfcc']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the VGG19 model function
def build_vgg19_model(input_shape, num_classes):
    base_model = tf.keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_vgg19_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: mfcc
# Epoch 1/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.6677 - accuracy: 0.6254 - val_loss: 0.6575 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.6609 - accuracy: 0.6254 - val_loss: 0.6578 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.6571 - accuracy: 0.6254 - val_loss: 0.6520 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 117s 2s/step - loss: 0.6547 - accuracy: 0.6254 - val_loss: 0.6513 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.6540 - accuracy: 0.6254 - val_loss: 0.6497 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 127s 2s/step - loss: 0.6538 - accuracy: 0.6254 - val_loss: 0.6462 - val_accuracy: 0.6286
# Epoch 7/50
# 60/60 [==============================] - 123s 2s/step - loss: 0.6502 - accuracy: 0.6254 - val_loss: 0.6455 - val_accuracy: 0.6286
# Epoch 8/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.6504 - accuracy: 0.6254 - val_loss: 0.6448 - val_accuracy: 0.6286
# Epoch 9/50
# 60/60 [==============================] - 115s 2s/step - loss: 0.6484 - accuracy: 0.6265 - val_loss: 0.6452 - val_accuracy: 0.6286
# Epoch 10/50
# 60/60 [==============================] - 114s 2s/step - loss: 0.6490 - accuracy: 0.6275 - val_loss: 0.6406 - val_accuracy: 0.6286
# Epoch 11/50
# 60/60 [==============================] - 115s 2s/step - loss: 0.6457 - accuracy: 0.6275 - val_loss: 0.6379 - val_accuracy: 0.6286
# Epoch 12/50
# 60/60 [==============================] - 113s 2s/step - loss: 0.6452 - accuracy: 0.6275 - val_loss: 0.6390 - val_accuracy: 0.6476
# Epoch 13/50
# 60/60 [==============================] - 112s 2s/step - loss: 0.6428 - accuracy: 0.6392 - val_loss: 0.6386 - val_accuracy: 0.6286
# Epoch 14/50
# 60/60 [==============================] - 113s 2s/step - loss: 0.6450 - accuracy: 0.6307 - val_loss: 0.6343 - val_accuracy: 0.6286
# Epoch 15/50
# 60/60 [==============================] - 112s 2s/step - loss: 0.6389 - accuracy: 0.6317 - val_loss: 0.6386 - val_accuracy: 0.6762
# Epoch 16/50
# 60/60 [==============================] - 112s 2s/step - loss: 0.6410 - accuracy: 0.6444 - val_loss: 0.6300 - val_accuracy: 0.6286
# Epoch 17/50
# 60/60 [==============================] - 112s 2s/step - loss: 0.6365 - accuracy: 0.6296 - val_loss: 0.6316 - val_accuracy: 0.6476
# Epoch 18/50
# 60/60 [==============================] - 113s 2s/step - loss: 0.6375 - accuracy: 0.6317 - val_loss: 0.6299 - val_accuracy: 0.6286
# Epoch 19/50
# 60/60 [==============================] - 107s 2s/step - loss: 0.6381 - accuracy: 0.6296 - val_loss: 0.6273 - val_accuracy: 0.6476
# Epoch 20/50
# 60/60 [==============================] - 113s 2s/step - loss: 0.6338 - accuracy: 0.6317 - val_loss: 0.6261 - val_accuracy: 0.6476
# Epoch 21/50
# 60/60 [==============================] - 112s 2s/step - loss: 0
# 60/60 [==============================] - 125s 2s/step - loss: 0.5819 - accuracy: 0.6931 - val_loss: 0.6425 - val_accuracy: 0.6095
# Epoch 2/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.5732 - accuracy: 0.7048 - val_loss: 0.6390 - val_accuracy: 0.6381
# Epoch 3/50
# 60/60 [==============================] - 127s 2s/step - loss: 0.5738 - accuracy: 0.6974 - val_loss: 0.6485 - val_accuracy: 0.6190
# Epoch 4/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.5724 - accuracy: 0.7048 - val_loss: 0.6422 - val_accuracy: 0.6476
# Epoch 5/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.5769 - accuracy: 0.6857 - val_loss: 0.6425 - val_accuracy: 0.6381
# Epoch 6/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.5713 - accuracy: 0.7037 - val_loss: 0.6469 - val_accuracy: 0.6095
# Epoch 7/50
# 60/60 [==============================] - 113s 2s/step - loss: 0.5689 - accuracy: 0.7037 - val_loss: 0.6460 - val_accuracy: 0.6381
# Fold 3 Results: Accuracy=63.81%, F1=0.60, Precision=0.61, Recall=0.64, Specificity=0.86, Kappa=0.13, ROC AUC=0.62
# Epoch 1/50
# 60/60 [==============================] - 120s 2s/step - loss: 0.5881 - accuracy: 0.6942 - val_loss: 0.5505 - val_accuracy: 0.7238
# Epoch 2/50
# 60/60 [==============================] - 117s 2s/step - loss: 0.5846 - accuracy: 0.6942 - val_loss: 0.5493 - val_accuracy: 0.7429
# Epoch 3/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.5811 - accuracy: 0.6931 - val_loss: 0.5509 - val_accuracy: 0.7524
# Epoch 4/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.5869 - accuracy: 0.6878 - val_loss: 0.5541 - val_accuracy: 0.7429
# Epoch 5/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.5829 - accuracy: 0.6804 - val_loss: 0.5526 - val_accuracy: 0.7524
# Epoch 6/50
# 60/60 [==============================] - 122s 2s/step - loss: 0.5815 - accuracy: 0.6963 - val_loss: 0.5515 - val_accuracy: 0.7524
# Epoch 7/50
# 60/60 [==============================] - 121s 2s/step - loss: 0.5828 - accuracy: 0.6921 - val_loss: 0.5508 - val_accuracy: 0.7238
# Fold 4 Results: Accuracy=74.29%, F1=0.72, Precision=0.76, Recall=0.74, Specificity=0.94, Kappa=0.39, ROC AUC=0.80
# Epoch 1/50
# 60/60 [==============================] - 122s 2s/step - loss: 0.5830 - accuracy: 0.6889 - val_loss: 0.5436 - val_accuracy: 0.7524
# Epoch 2/50
# 60/60 [==============================] - 123s 2s/step - loss: 0.5804 - accuracy: 0.6910 - val_loss: 0.5450 - val_accuracy: 0.7524
# Epoch 3/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.5822 - accuracy: 0.6974 - val_loss: 0.5441 - val_accuracy: 0.7619
# Epoch 4/50
# 60/60 [==============================] - 122s 2s/step - loss: 0.5799 - accuracy: 0.6868 - val_loss: 0.5511 - val_accuracy: 0.7238
# Epoch 5/50
# 60/60 [==============================] - 124s 2s/step - loss: 0.5840 - accuracy: 0.6794 - val_loss: 0.5446 - val_accuracy: 0.7714
# Epoch 6/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.5782 - accuracy: 0.6847 - val_loss: 0.5525 - val_accuracy: 0.7238
# Fold 5 Results: Accuracy=75.24%, F1=0.73, Precision=0.76, Recall=0.75, Specificity=0.92, Kappa=0.42, ROC AUC=0.79
# Epoch 1/50
# 60/60 [==============================] - 122s 2s/step - loss: 0.5781 - accuracy: 0.7016 - val_loss: 0.6025 - val_accuracy: 0.6762
# Epoch 2/50
# 60/60 [==============================] - 130s 2s/step - loss: 0.5763 - accuracy: 0.7101 - val_loss: 0.5865 - val_accuracy: 0.6857
# Epoch 3/50
# 60/60 [==============================] - 125s 2s/step - loss: 0.5799 - accuracy: 0.7143 - val_loss: 0.5885 - val_accuracy: 0.6190
# Epoch 4/50
# 60/60 [==============================] - 133s 2s/step - loss: 0.5763 - accuracy: 0.7026 - val_loss: 0.5938 - val_accuracy: 0.6857
# Epoch 5/50
# 60/60 [==============================] - 130s 2s/step - loss: 0.5724 - accuracy: 0.7069 - val_loss: 0.5864 - val_accuracy: 0.6571
# Epoch 6/50
# 60/60 [==============================] - 118s 2s/step - loss: 0.5713 - accuracy: 0.7037 - val_loss: 0.5880 - val_accuracy: 0.6476
# Epoch 7/50
# 60/60 [==============================] - 117s 2s/step - loss: 0.5709 - accuracy: 0.7026 - val_loss: 0.5869 - val_accuracy: 0.6857
# Epoch 8/50
# 60/60 [==============================] - 114s 2s/step - loss: 0.5713 - accuracy: 0.7037 - val_loss: 0.5905 - val_accuracy: 0.7048
# Epoch 9/50
# 60/60 [==============================] - 114s 2s/step - loss: 0.5699 - accuracy: 0.7132 - val_loss: 0.5932 - val_accuracy: 0.6952
# Epoch 10/50
# 60/60 [==============================] - 114s 2s/step - loss: 0.5673 - accuracy: 0.7037 - val_loss: 0.5875 - val_accuracy: 0.6762
# Fold 6 Results: Accuracy=65.71%, F1=0.61, Precision=0.64, Recall=0.66, Specificity=0.91, Kappa=0.16, ROC AUC=0.72
# Epoch 1/50
# 60/60 [==============================] - 119s 2s/step - loss: 0.5777 - accuracy: 0.6910 - val_loss: 0.5418 - val_accuracy: 0.6857
# Epoch 2/50
# 60/60 [==============================] - 121s 2s/step - loss: 0.5790 - accuracy: 0.6931 - val_loss: 0.5425 - val_accuracy: 0.6952
# Epoch 3/50
# 60/60 [==============================] - 122s 2s/step - loss: 0.5760 - accuracy: 0.6984 - val_loss: 0.5392 - val_accuracy: 0.7333
# Epoch 4/50
# 60/60 [==============================] - 123s 2s/step - loss: 0.5756 - accuracy: 0.6974 - val_loss: 0.5367 - val_accuracy: 0.7619
# Epoch 5/50
# 60/60 [==============================] - 112s 2s/step - loss: 0
50
# 60/60 [==============================] - 112s 2s/step - loss: 0.5379 - accuracy: 0.7196 - val_loss: 0.5491 - val_accuracy: 0.7238
# Epoch 38/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.5393 - accuracy: 0.7217 - val_loss: 0.5496 - val_accuracy: 0.7333
# Epoch 39/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.5366 - accuracy: 0.7259 - val_loss: 0.5517 - val_accuracy: 0.7333
# Epoch 40/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.5369 - accuracy: 0.7323 - val_loss: 0.5494 - val_accuracy: 0.7238
# Epoch 41/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.5358 - accuracy: 0.7323 - val_loss: 0.5492 - val_accuracy: 0.7143
# Epoch 42/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.5359 - accuracy: 0.7333 - val_loss: 0.5498 - val_accuracy: 0.7143
# Fold 8 Results: Accuracy=72.38%, F1=0.71, Precision=0.72, Recall=0.72, Specificity=0.88, Kappa=0.38, ROC AUC=0.79
# Epoch 1/50
# 60/60 [==============================] - 112s 2s/step - loss: 0.5438 - accuracy: 0.7312 - val_loss: 0.5306 - val_accuracy: 0.7238
# Epoch 2/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.5371 - accuracy: 0.7323 - val_loss: 0.5496 - val_accuracy: 0.7048
# Epoch 3/50
# 60/60 [==============================] - 117s 2s/step - loss: 0.5438 - accuracy: 0.7175 - val_loss: 0.5599 - val_accuracy: 0.6857
# Epoch 4/50
# 60/60 [==============================] - 72s 1s/step - loss: 0.5440 - accuracy: 0.7228 - val_loss: 0.5338 - val_accuracy: 0.7238
# Epoch 5/50
# 60/60 [==============================] - 64s 1s/step - loss: 0.5422 - accuracy: 0.7228 - val_loss: 0.5365 - val_accuracy: 0.7333
# Epoch 6/50
# 60/60 [==============================] - 67s 1s/step - loss: 0.5436 - accuracy: 0.7132 - val_loss: 0.5338 - val_accuracy: 0.7333
# Fold 9 Results: Accuracy=72.38%, F1=0.72, Precision=0.72, Recall=0.72, Specificity=0.82, Kappa=0.40, ROC AUC=0.81
# Epoch 1/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.5397 - accuracy: 0.7228 - val_loss: 0.5764 - val_accuracy: 0.6762
# Epoch 2/50
# 60/60 [==============================] - 77s 1s/step - loss: 0.5357 - accuracy: 0.7206 - val_loss: 0.5781 - val_accuracy: 0.6857
# Epoch 3/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.5389 - accuracy: 0.7206 - val_loss: 0.5733 - val_accuracy: 0.7048
# Epoch 4/50
# 60/60 [==============================] - 131s 2s/step - loss: 0.5337 - accuracy: 0.7333 - val_loss: 0.5757 - val_accuracy: 0.6762
# Epoch 5/50
# 60/60 [==============================] - 126s 2s/step - loss: 0.5346 - accuracy: 0.7376 - val_loss: 0.5738 - val_accuracy: 0.7048
# Epoch 6/50
# 60/60 [==============================] - 123s 2s/step - loss: 0.5303 - accuracy: 0.7365 - val_loss: 0.5850 - val_accuracy: 0.6667
# Epoch 7/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.5310 - accuracy: 0.7249 - val_loss: 0.5762 - val_accuracy: 0.6857
# Epoch 8/50
# 60/60 [==============================] - 128s 2s/step - loss: 0.5322 - accuracy: 0.7323 - val_loss: 0.5754 - val_accuracy: 0.6857
# Fold 10 Results: Accuracy=70.48%, F1=0.69, Precision=0.70, Recall=0.70, Specificity=0.86, Kappa=0.33, ROC AUC=0.75
# Mean and Std Dev of Performance Metrics for Spectrogram mfcc:
# Fold                    5.500000
# Accuracy               70.761905
# F1 Score                0.680434
# Precision               0.705411
# Recall                  0.707619
# Specificity             0.894779
# Kappa                   0.312704
# ROC AUC                 0.757334
# Training Time (s)    2554.373431
# Testing Time (s)       12.321335
# dtype: float64
# Fold                    3.027650
# Accuracy                4.115980
# F1 Score                0.055737
# Precision               0.049954
# Recall                  0.041160
# Specificity             0.042761
# Kappa                   0.117234
# ROC AUC                 0.059357
# Training Time (s)    2281.516394
# Testing Time (s)        2.050663
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['mfcc']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the ResNet50 model function
def build_resnet50_model(input_shape, num_classes):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_resnet50_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: mfcc
# Epoch 1/50
# 60/60 [==============================] - 68s 1s/step - loss: 0.6732 - accuracy: 0.5926 - val_loss: 0.6598 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 65s 1s/step - loss: 0.6631 - accuracy: 0.6254 - val_loss: 0.6595 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.6617 - accuracy: 0.6254 - val_loss: 0.6598 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.6622 - accuracy: 0.6254 - val_loss: 0.6591 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 60s 1s/step - loss: 0.6626 - accuracy: 0.6254 - val_loss: 0.6593 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.6622 - accuracy: 0.6254 - val_loss: 0.6598 - val_accuracy: 0.6286
# Epoch 7/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.6614 - accuracy: 0.6254 - val_loss: 0.6589 - val_accuracy: 0.6286
# Epoch 8/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.6621 - accuracy: 0.6254 - val_loss: 0.6589 - val_accuracy: 0.6286
# Epoch 9/50
# 60/60 [==============================] - 60s 1s/step - loss: 0.6612 - accuracy: 0.6254 - val_loss: 0.6588 - val_accuracy: 0.6286
# 60/60 [==============================] - 32s 535ms/step - loss: 0.6537 - accuracy: 0.6392 - val_loss: 0.6454 - val_accuracy: 0.6381
# Epoch 11/50
# 60/60 [==============================] - 32s 532ms/step - loss: 0.6526 - accuracy: 0.6381 - val_loss: 0.6501 - val_accuracy: 0.6286
# Epoch 12/50
# 60/60 [==============================] - 32s 541ms/step - loss: 0.6559 - accuracy: 0.6360 - val_loss: 0.6479 - val_accuracy: 0.6381
# Fold 10 Results: Accuracy=63.81%, F1=0.52, Precision=0.77, Recall=0.64, Specificity=1.00, Kappa=0.06, ROC AUC=0.65
# Mean and Std Dev of Performance Metrics for Spectrogram mfcc:
# Fold                    5.500000
# Accuracy               62.857143
# F1 Score                0.492587
# Precision               0.472465
# Recall                  0.628571
# Specificity             0.995385
# Kappa                   0.012625
# ROC AUC                 0.597478
# Training Time (s)    4397.078968
# Testing Time (s)        7.178485
# dtype: float64
# Fold                    3.027650
# Accuracy                0.777616
# F1 Score                0.016002
# Precision               0.139436
# Recall                  0.007776
# Specificity             0.010384
# Kappa                   0.028665
# ROC AUC                 0.078437
# Training Time (s)    7358.155640
# Testing Time (s)        4.151982
# dtype: float64

# %%
#Type 3 MFCC

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['stft']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the MobileNetV2 model function
def build_mobilenetv2_model(input_shape, num_classes):
    base_model = tf.keras.applications.MobileNetV2(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_mobilenetv2_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: stft
# Epoch 1/50
# 60/60 [==============================] - 35s 587ms/step - loss: 0.6559 - accuracy: 0.6402 - val_loss: 0.6594 - val_accuracy: 0.6000
# Epoch 2/50
# 60/60 [==============================] - 24s 400ms/step - loss: 0.5495 - accuracy: 0.7238 - val_loss: 0.6030 - val_accuracy: 0.6381
# Epoch 3/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.5088 - accuracy: 0.7714 - val_loss: 0.5907 - val_accuracy: 0.6381
# Epoch 4/50
# 60/60 [==============================] - 25s 411ms/step - loss: 0.4674 - accuracy: 0.7979 - val_loss: 0.6395 - val_accuracy: 0.6667
# Epoch 5/50
# 60/60 [==============================] - 25s 422ms/step - loss: 0.4428 - accuracy: 0.7968 - val_loss: 0.5762 - val_accuracy: 0.7048
# Epoch 6/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.4173 - accuracy: 0.8328 - val_loss: 0.5638 - val_accuracy: 0.6952
# Epoch 7/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.3918 - accuracy: 0.8497 - val_loss: 0.5542 - val_accuracy: 0.6857
# Epoch 8/50
# 60/60 [==============================] - 24s 397ms/step - loss: 0.3826 - accuracy: 0.8582 - val_loss: 0.5738 - val_accuracy: 0.7143
# Epoch 9/50
# 60/60 [==============================] - 23s 388ms/step - loss: 0.3553 - accuracy: 0.8688 - val_loss: 0.5747 - val_accuracy: 0.7143
# Epoch 10/50
# 60/60 [==============================] - 26s 426ms/step - loss: 0.3370 - accuracy: 0.8815 - val_loss: 0.5740 - val_accuracy: 0.7143
# Epoch 11/50
# 60/60 [==============================] - 24s 402ms/step - loss: 0.3269 - accuracy: 0.8899 - val_loss: 0.5796 - val_accuracy: 0.7048
# Epoch 12/50
# 60/60 [==============================] - 25s 411ms/step - loss: 0.3127 - accuracy: 0.8783 - val_loss: 0.5746 - val_accuracy: 0.7143
# Fold 1 Results: Accuracy=68.57%, F1=0.68, Precision=0.68, Recall=0.69, Specificity=0.80, Kappa=0.30, ROC AUC=0.77
# Epoch 1/50
# 60/60 [==============================] - 30s 495ms/step - loss: 0.4027 - accuracy: 0.8444 - val_loss: 0.3884 - val_accuracy: 0.8286
# Epoch 2/50
# 60/60 [==============================] - 25s 412ms/step - loss: 0.3682 - accuracy: 0.8635 - val_loss: 0.3952 - val_accuracy: 0.8000
# Epoch 3/50
# 60/60 [==============================] - 25s 420ms/step - loss: 0.3490 - accuracy: 0.8677 - val_loss: 0.4286 - val_accuracy: 0.7810
# Epoch 4/50
# 60/60 [==============================] - 27s 443ms/step - loss: 0.3295 - accuracy: 0.8836 - val_loss: 0.3930 - val_accuracy: 0.8476
# Epoch 5/50
# 60/60 [==============================] - 25s 418ms/step - loss: 0.3077 - accuracy: 0.8931 - val_loss: 0.4006 - val_accuracy: 0.7905
# Epoch 6/50
# 60/60 [==============================] - 25s 416ms/step - loss: 0.2883 - accuracy: 0.8995 - val_loss: 0.4006 - val_accuracy: 0.7905
# Fold 2 Results: Accuracy=82.86%, F1=0.82, Precision=0.83, Recall=0.83, Specificity=0.92, Kappa=0.62, ROC AUC=0.91
# Epoch 1/50
# 60/60 [==============================] - 29s 489ms/step - loss: 0.3774 - accuracy: 0.8561 - val_loss: 0.3547 - val_accuracy: 0.8667
# Epoch 2/50
# 60/60 [==============================] - 25s 408ms/step - loss: 0.3472 - accuracy: 0.8720 - val_loss: 0.3704 - val_accuracy: 0.8286
# Epoch 3/50
# 60/60 [==============================] - 24s 405ms/step - loss: 0.3285 - accuracy: 0.8720 - val_loss: 0.3806 - val_accuracy: 0.8095
# Epoch 4/50
# 60/60 [==============================] - 24s 407ms/step - loss: 0.3126 - accuracy: 0.8836 - val_loss: 0.3957 - val_accuracy: 0.8000
# Epoch 5/50
# 60/60 [==============================] - 25s 425ms/step - loss: 0.3019 - accuracy: 0.8995 - val_loss: 0.3808 - val_accuracy: 0.8095
# Epoch 6/50
# 60/60 [==============================] - 25s 419ms/step - loss: 0.2778 - accuracy: 0.9153 - val_loss: 0.3638 - val_accuracy: 0.8476
# Fold 3 Results: Accuracy=86.67%, F1=0.87, Precision=0.87, Recall=0.87, Specificity=0.89, Kappa=0.71, ROC AUC=0.94
# Epoch 1/50
# 60/60 [==============================] - 28s 465ms/step - loss: 0.3619 - accuracy: 0.8635 - val_loss: 0.3339 - val_accuracy: 0.8762
# Epoch 2/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.3287 - accuracy: 0.8730 - val_loss: 0.3490 - val_accuracy: 0.8571
# Epoch 3/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.3143 - accuracy: 0.8889 - val_loss: 0.3461 - val_accuracy: 0.8571
# Epoch 4/50
# 60/60 [==============================] - 25s 415ms/step - loss: 0.2909 - accuracy: 0.9058 - val_loss: 0.3528 - val_accuracy: 0.8667
# Epoch 5/50
# 60/60 [==============================] - 24s 402ms/step - loss: 0.2735 - accuracy: 0.9206 - val_loss: 0.3533 - val_accuracy: 0.8476
# Epoch 6/50
# 60/60 [==============================] - 25s 416ms/step - loss: 0.2571 - accuracy: 0.9238 - val_loss: 0.3473 - val_accuracy: 0.8667
# Fold 4 Results: Accuracy=87.62%, F1=0.88, Precision=0.88, Recall=0.88, Specificity=0.91, Kappa=0.73, ROC AUC=0.95
# Epoch 1/50
# 60/60 [==============================] - 27s 445ms/step - loss: 0.3442 - accuracy: 0.8741 - val_loss: 0.2818 - val_accuracy: 0.9048
# Epoch 2/50
# 60/60 [==============================] - 24s 408ms/step - loss: 0.3177 - accuracy: 0.8730 - val_loss: 0.2906 - val_accuracy: 0.8857
# Epoch 3/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.3011 - accuracy: 0.8931 - val_loss: 0.2911 - val_accuracy: 0.8857
# Epoch 4/50
# 60/60 [==============================] - 23s 389ms/step - loss: 0.2811 - accuracy: 0.9048 - val_loss: 0.2878 - val_accuracy: 0.8952
# Epoch 5/50
# 60/60 [==============================] - 24s 407ms/step - loss: 0.2576 - accuracy: 0.9280 - val_loss: 0.3072 - val_accuracy: 0.8857
# Epoch 6/50
# 60/60 [==============================] - 25s 410ms/step - loss: 0.2406 - accuracy: 0.9333 - val_loss: 0.2910 - val_accuracy: 0.8952
# Fold 5 Results: Accuracy=90.48%, F1=0.90, Precision=0.91, Recall=0.90, Specificity=0.98, Kappa=0.79, ROC AUC=0.97
# Epoch 1/50
# 60/60 [==============================] - 27s 446ms/step - loss: 0.3167 - accuracy: 0.8783 - val_loss: 0.3485 - val_accuracy: 0.8857
# Epoch 2/50
# 60/60 [==============================] - 23s 387ms/step - loss: 0.2923 - accuracy: 0.9048 - val_loss: 0.3252 - val_accuracy: 0.8571
# Epoch 3/50
# 60/60 [==============================] - 22s 375ms/step - loss: 0.2690 - accuracy: 0.9101 - val_loss: 0.3606 - val_accuracy: 0.8571
# Epoch 4/50
# 60/60 [==============================] - 25s 409ms/step - loss: 0.2658 - accuracy: 0.9090 - val_loss: 0.3279 - val_accuracy: 0.8476
# Epoch 5/50
# 60/60 [==============================] - 24s 407ms/step - loss: 0.2402 - accuracy: 0.9270 - val_loss: 0.3344 - val_accuracy: 0.8571
# Epoch 6/50
# 60/60 [==============================] - 24s 393ms/step - loss: 0.2215 - accuracy: 0.9354 - val_loss: 0.3365 - val_accuracy: 0.8476
# Epoch 7/50
# 60/60 [==============================] - 24s 399ms/step - loss: 0.2180 - accuracy: 0.9376 - val_loss: 0.3252 - val_accuracy: 0.8476
# Epoch 8/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.1964 - accuracy: 0.9471 - val_loss: 0.3279 - val_accuracy: 0.8476
# Epoch 9/50
# 60/60 [==============================] - 25s 413ms/step - loss: 0.1896 - accuracy: 0.9503 - val_loss: 0.3424 - val_accuracy: 0.8476
# Epoch 10/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.1830 - accuracy: 0.9450 - val_loss: 0.3667 - val_accuracy: 0.8381
# Epoch 11/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.1620 - accuracy: 0.9714 - val_loss: 0.3481 - val_accuracy: 0.8381
# Epoch 12/50
# 60/60 [==============================] - 23s 388ms/step - loss: 0.1649 - accuracy: 0.9640 - val_loss: 0.3503 - val_accuracy: 0.8286
# Fold 6 Results: Accuracy=84.76%, F1=0.85, Precision=0.85, Recall=0.85, Specificity=0.91, Kappa=0.67, ROC AUC=0.93
# Epoch 1/50
# 60/60 [==============================] - 27s 450ms/step - loss: 0.2236 - accuracy: 0.9344 - val_loss: 0.2128 - val_accuracy: 0.9238
# Epoch 2/50
# 60/60 [==============================] - 24s 398ms/step - loss: 0.1977 - accuracy: 0.9439 - val_loss: 0.2204 - val_accuracy: 0.9143
# Epoch 3/50
# 60/60 [==============================] - 24s 408ms/step - loss: 0.1782 - accuracy: 0.9577 - val_loss: 0.2174 - val_accuracy: 0.9143
# Epoch 4/50
# 60/60 [==============================] - 25s 411ms/step - loss: 0.1628 - accuracy: 0.9704 - val_loss: 0.2177 - val_accuracy: 0.9333
# Epoch 5/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.1551 - accuracy: 0.9714 - val_loss: 0.2815 - val_accuracy: 0.8762
# Epoch 6/50
# 60/60 [==============================] - 24s 401ms/step - loss: 0.1400 - accuracy: 0.9757 - val_loss: 0.2229 - val_accuracy: 0.9238
# Fold 7 Results: Accuracy=92.38%, F1=0.92, Precision=0.93, Recall=0.92, Specificity=0.98, Kappa=0.83, ROC AUC=0.98
# Epoch 1/50
# 60/60 [==============================] - 22s 367ms/step - loss: 0.2086 - accuracy: 0.9386 - val_loss: 0.1975 - val_accuracy: 0.9524
# Epoch 2/50
# 60/60 [==============================] - 11s 175ms/step - loss: 0.1828 - accuracy: 0.9545 - val_loss: 0.1961 - val_accuracy: 0.9238
# Epoch 3/50
# 60/60 [==============================] - 25s 411ms/step - loss: 0.1647 - accuracy: 0.9619 - val_loss: 0.2007 - val_accuracy: 0.9429
# Epoch 4/50
# Epoch 7/50
# 60/60 [==============================] - 26s 437ms/step - loss: 0.0712 - accuracy: 0.9979 - val_loss: 0.1364 - val_accuracy: 0.9810
# Epoch 8/50
# 60/60 [==============================] - 26s 426ms/step - loss: 0.0671 - accuracy: 0.9968 - val_loss: 0.1255 - val_accuracy: 0.9524
# Fold 10 Results: Accuracy=97.14%, F1=0.97, Precision=0.97, Recall=0.97, Specificity=1.00, Kappa=0.94, ROC AUC=1.00
# Mean and Std Dev of Performance Metrics for Spectrogram stft:
# Fold                   5.500000
# Accuracy              88.000000
# F1 Score               0.878020
# Precision              0.880375
# Recall                 0.880000
# Specificity            0.936294
# Kappa                  0.736523
# ROC AUC                0.944613
# Training Time (s)    208.673983
# Testing Time (s)      12.508245
# dtype: float64
# Fold                  3.027650
# Accuracy              8.353490
# F1 Score              0.085663
# Precision             0.086577
# Recall                0.083535
# Specificity           0.061751
# Kappa                 0.186320
# ROC AUC               0.068054
# Training Time (s)    62.268072
# Testing Time (s)     21.364041
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['stft']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the VGG19 model function
def build_vgg19_model(input_shape, num_classes):
    base_model = tf.keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_vgg19_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: stft
# Epoch 1/50
# 60/60 [==============================] - 59s 987ms/step - loss: 0.6789 - accuracy: 0.6000 - val_loss: 0.6571 - val_accuracy: 0.6381
# Epoch 2/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.6645 - accuracy: 0.6243 - val_loss: 0.6521 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 64s 1s/step - loss: 0.6552 - accuracy: 0.6254 - val_loss: 0.6522 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 68s 1s/step - loss: 0.6513 - accuracy: 0.6254 - val_loss: 0.6503 - val_accuracy: 0.6381
# Epoch 5/50
# 60/60 [==============================] - 69s 1s/step - loss: 0.6458 - accuracy: 0.6360 - val_loss: 0.6570 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 65s 1s/step - loss: 0.6413 - accuracy: 0.6328 - val_loss: 0.6542 - val_accuracy: 0.6286
# Epoch 7/50
# Epoch 7/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.5798 - accuracy: 0.7132 - val_loss: 0.5980 - val_accuracy: 0.6762
# Epoch 8/50
# 60/60 [==============================] - 60s 1s/step - loss: 0.5753 - accuracy: 0.7016 - val_loss: 0.5991 - val_accuracy: 0.7333
# Epoch 9/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.5761 - accuracy: 0.7048 - val_loss: 0.5887 - val_accuracy: 0.6762
# Epoch 10/50
# 60/60 [==============================] - 60s 1s/step - loss: 0.5756 - accuracy: 0.6963 - val_loss: 0.5916 - val_accuracy: 0.6762
# Epoch 11/50
# 60/60 [==============================] - 60s 1s/step - loss: 0.5721 - accuracy: 0.7175 - val_loss: 0.5907 - val_accuracy: 0.6857
# Epoch 12/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.5692 - accuracy: 0.7249 - val_loss: 0.5905 - val_accuracy: 0.6952
# Epoch 13/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.5674 - accuracy: 0.7164 - val_loss: 0.5890 - val_accuracy: 0.6952
# Epoch 14/50
# 60/60 [==============================] - 64s 1s/step - loss: 0.5673 - accuracy: 0.7228 - val_loss: 0.5899 - val_accuracy: 0.6952
# Fold 3 Results: Accuracy=67.62%, F1=0.64, Precision=0.67, Recall=0.68, Specificity=0.89, Kappa=0.23, ROC AUC=0.74
# Epoch 1/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.5786 - accuracy: 0.7026 - val_loss: 0.5551 - val_accuracy: 0.7238
# Epoch 2/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.5736 - accuracy: 0.7016 - val_loss: 0.5550 - val_accuracy: 0.7333
# Epoch 3/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.5711 - accuracy: 0.6995 - val_loss: 0.5548 - val_accuracy: 0.7333
# Epoch 4/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.5688 - accuracy: 0.7238 - val_loss: 0.5536 - val_accuracy: 0.7333
# Epoch 5/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.5657 - accuracy: 0.7206 - val_loss: 0.5526 - val_accuracy: 0.7429
# Epoch 6/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.5632 - accuracy: 0.7175 - val_loss: 0.5563 - val_accuracy: 0.7810
# Epoch 7/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.5624 - accuracy: 0.7344 - val_loss: 0.5582 - val_accuracy: 0.6762
# Epoch 8/50
# 60/60 [==============================] - 63s 1s/step - loss: 0.5610 - accuracy: 0.7354 - val_loss: 0.5511 - val_accuracy: 0.7048
# Epoch 9/50
# 60/60 [==============================] - 62s 1s/step - loss: 0.5614 - accuracy: 0.7291 - val_loss: 0.5492 - val_accuracy: 0.7619
# Epoch 10/50
# 60/60 [==============================] - 61s 1s/step - loss: 0.5531 - accuracy: 0.7418 - val_loss: 0.5534 - val_accuracy: 0.6762
# Epoch 11/50
50
# 60/60 [==============================] - 112s 2s/step - loss: 0.4271 - accuracy: 0.8180 - val_loss: 0.4556 - val_accuracy: 0.8095
# Epoch 7/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.4175 - accuracy: 0.8180 - val_loss: 0.4355 - val_accuracy: 0.8190
# Epoch 8/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.4178 - accuracy: 0.8201 - val_loss: 0.4356 - val_accuracy: 0.8190
# Epoch 9/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.4122 - accuracy: 0.8233 - val_loss: 0.4376 - val_accuracy: 0.8190
# Epoch 10/50
# 60/60 [==============================] - 111s 2s/step - loss: 0.4127 - accuracy: 0.8265 - val_loss: 0.4414 - val_accuracy: 0.8286
# Epoch 11/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.4095 - accuracy: 0.8222 - val_loss: 0.4433 - val_accuracy: 0.8000
# Epoch 12/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.4190 - accuracy: 0.8169 - val_loss: 0.4373 - val_accuracy: 0.8190
# Fold 10 Results: Accuracy=81.90%, F1=0.81, Precision=0.82, Recall=0.82, Specificity=0.91, Kappa=0.60, ROC AUC=0.87
# Mean and Std Dev of Performance Metrics for Spectrogram stft:
# Fold                    5.500000
# Accuracy               75.238095
# F1 Score                0.724077
# Precision               0.765224
# Recall                  0.752381
# Specificity             0.919184
# Kappa                   0.414727
# ROC AUC                 0.810164
# Training Time (s)    6775.177755
# Testing Time (s)        6.963874
# dtype: float64
# Fold                     3.027650
# Accuracy                 7.280854
# F1 Score                 0.108055
# Precision                0.066806
# Recall                   0.072809
# Specificity              0.042205
# Kappa                    0.210632
# ROC AUC                  0.099911
# Training Time (s)    17955.165689
# Testing Time (s)         1.825321
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['stft']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the ResNet50 model function
def build_resnet50_model(input_shape, num_classes):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_resnet50_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: stft
# Epoch 1/50
# 60/60 [==============================] - 44s 738ms/step - loss: 0.6680 - accuracy: 0.6159 - val_loss: 0.6577 - val_accuracy: 0.6286
# 60/60 [==============================] - 42s 692ms/step - loss: 0.5625 - accuracy: 0.7238 - val_loss: 0.5650 - val_accuracy: 0.7143
# Fold 10 Results: Accuracy=71.43%, F1=0.69, Precision=0.71, Recall=0.71, Specificity=0.89, Kappa=0.34, ROC AUC=0.75
# Mean and Std Dev of Performance Metrics for Spectrogram stft:
# Fold                    5.500000
# Accuracy               70.285714
# F1 Score                0.634201
# Precision               0.655390
# Recall                  0.702857
# Specificity             0.963217
# Kappa                   0.252483
# ROC AUC                 0.699816
# Training Time (s)    1048.359793
# Testing Time (s)        7.181410
# dtype: float64
# Fold                   3.027650
# Accuracy               6.152509
# F1 Score               0.117674
# Precision              0.181707
# Recall                 0.061525
# Specificity            0.041792
# Kappa                  0.204964
# ROC AUC                0.095035
# Training Time (s)    677.856503
# Testing Time (s)       0.552063
# dtype: float64

# %%
CQT

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['cqt']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the ResNet50 model function
def build_resnet50_model(input_shape, num_classes):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_resnet50_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: cqt
# Epoch 1/50
# 60/60 [==============================] - 117s 2s/step - loss: 0.6641 - accuracy: 0.6254 - val_loss: 0.6599 - val_accuracy: 0.6286
# Epoch 2/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.6616 - accuracy: 0.6254 - val_loss: 0.6600 - val_accuracy: 0.6286
# Epoch 3/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.6621 - accuracy: 0.6254 - val_loss: 0.6584 - val_accuracy: 0.6286
# Epoch 4/50
# 60/60 [==============================] - 110s 2s/step - loss: 0.6604 - accuracy: 0.6254 - val_loss: 0.6578 - val_accuracy: 0.6286
# Epoch 5/50
# 60/60 [==============================] - 104s 2s/step - loss: 0.6598 - accuracy: 0.6254 - val_loss: 0.6595 - val_accuracy: 0.6286
# Epoch 6/50
# 60/60 [==============================] - 103s 2s/step - loss: 0.6592 - accuracy: 0.6254 - val_loss: 0.6566 - val_accuracy: 0.6286
# Epoch 7/50
# 60/60 [==============================] - 102s 2s/step - loss: 0.6584 - accuracy: 0.6254 - val_loss: 0.6569 - val_accuracy: 0.6286
# Epoch 8/50
# 60/60 [==============================] - 101s 2s/step - loss: 0.6546 - accuracy: 0.6254 - val_loss: 0.6585 - val_accuracy: 0.6286
# Epoch 37/50
# 60/60 [==============================] - 100s 2s/step - loss: 0.6034 - accuracy: 0.6825 - val_loss: 0.6106 - val_accuracy: 0.7333
# Epoch 38/50
# 60/60 [==============================] - 101s 2s/step - loss: 0.6048 - accuracy: 0.6825 - val_loss: 0.6102 - val_accuracy: 0.7333
# Epoch 39/50
# 60/60 [==============================] - 102s 2s/step - loss: 0.6020 - accuracy: 0.6899 - val_loss: 0.6102 - val_accuracy: 0.7143
# Epoch 40/50
# 60/60 [==============================] - 104s 2s/step - loss: 0.6011 - accuracy: 0.6857 - val_loss: 0.6128 - val_accuracy: 0.6762
# Epoch 41/50
# 60/60 [==============================] - 104s 2s/step - loss: 0.6092 - accuracy: 0.6921 - val_loss: 0.6095 - val_accuracy: 0.7143
# Epoch 42/50
# 60/60 [==============================] - 105s 2s/step - loss: 0.6003 - accuracy: 0.6899 - val_loss: 0.6081 - val_accuracy: 0.7429
# Epoch 43/50
# 60/60 [==============================] - 103s 2s/step - loss: 0.5997 - accuracy: 0.6942 - val_loss: 0.6081 - val_accuracy: 0.7048
# Epoch 44/50
# 60/60 [==============================] - 101s 2s/step - loss: 0.6007 - accuracy: 0.6984 - val_loss: 0.6080 - val_accuracy: 0.7048
# Epoch 45/50
# 60/60 [==============================] - 93s 2s/step - loss: 0.6003 - accuracy: 0.6825 - val_loss: 0.6076 - val_accuracy: 0.7238
# Epoch 46/50
# 60/60 [==============================] - 99s 2s/step - loss: 0.5987 - accuracy: 0.6952 - val_loss: 0.6074 - val_accuracy: 0.7048
# Epoch 47/50
# 60/60 [==============================] - 19214s 320s/step - loss: 0.5972 - accuracy: 0.6783 - val_loss: 0.6111 - val_accuracy: 0.7048
# Epoch 48/50
# 60/60 [==============================] - 85s 1s/step - loss: 0.6005 - accuracy: 0.7037 - val_loss: 0.6052 - val_accuracy: 0.7429
# Epoch 49/50
# 60/60 [==============================] - 86s 1s/step - loss: 0.5976 - accuracy: 0.6942 - val_loss: 0.6049 - val_accuracy: 0.7429
# Epoch 50/50
# 60/60 [==============================] - 89s 1s/step - loss: 0.6004 - accuracy: 0.6952 - val_loss: 0.6044 - val_accuracy: 0.7333
# Fold 2 Results: Accuracy=73.33%, F1=0.72, Precision=0.73, Recall=0.73, Specificity=0.88, Kappa=0.39, ROC AUC=0.70
# Epoch 1/50
# 60/60 [==============================] - 96s 2s/step - loss: 0.6022 - accuracy: 0.6910 - val_loss: 0.6072 - val_accuracy: 0.6667
# Epoch 2/50
# 60/60 [==============================] - 91s 2s/step - loss: 0.6045 - accuracy: 0.6783 - val_loss: 0.6010 - val_accuracy: 0.7048
# Epoch 3/50
# 60/60 [==============================] - 90s 2s/step - loss: 0.5981 - accuracy: 0.6942 - val_loss: 0.6022 - val_accuracy: 0.6857
# Epoch 4/50
# 60/60 [==============================] - 91s 2s/step - loss: 0.5946 - accuracy: 0.7079 - val_loss: 0.6092 - val_accuracy: 0.6286
# Epoch 5/50
# Epoch 5/50
# 60/60 [==============================] - 36s 608ms/step - loss: 0.5407 - accuracy: 0.7344 - val_loss: 0.5713 - val_accuracy: 0.7048
# Epoch 6/50
# 60/60 [==============================] - 38s 626ms/step - loss: 0.5286 - accuracy: 0.7619 - val_loss: 0.5765 - val_accuracy: 0.6762
# Fold 7 Results: Accuracy=68.57%, F1=0.66, Precision=0.67, Recall=0.69, Specificity=0.86, Kappa=0.27, ROC AUC=0.72
# Epoch 1/50
# 60/60 [==============================] - 48s 795ms/step - loss: 0.5349 - accuracy: 0.7418 - val_loss: 0.5834 - val_accuracy: 0.6952
# Epoch 2/50
# 60/60 [==============================] - 40s 664ms/step - loss: 0.5364 - accuracy: 0.7471 - val_loss: 0.5717 - val_accuracy: 0.6952
# Epoch 3/50
# 60/60 [==============================] - 39s 647ms/step - loss: 0.5372 - accuracy: 0.7460 - val_loss: 0.5610 - val_accuracy: 0.7333
# Epoch 4/50
# 60/60 [==============================] - 39s 653ms/step - loss: 0.5310 - accuracy: 0.7566 - val_loss: 0.5606 - val_accuracy: 0.7429
# Epoch 5/50
# 60/60 [==============================] - 41s 691ms/step - loss: 0.5275 - accuracy: 0.7587 - val_loss: 0.5746 - val_accuracy: 0.7143
# Epoch 6/50
# 60/60 [==============================] - 39s 658ms/step - loss: 0.5348 - accuracy: 0.7545 - val_loss: 0.5618 - val_accuracy: 0.7333
# Epoch 7/50
# 60/60 [==============================] - 40s 659ms/step - loss: 0.5307 - accuracy: 0.7566 - val_loss: 0.5620 - val_accuracy: 0.7524
# Epoch 8/50
# 60/60 [==============================] - 41s 678ms/step - loss: 0.5269 - accuracy: 0.7503 - val_loss: 0.5607 - val_accuracy: 0.7429
# Epoch 9/50
# 60/60 [==============================] - 39s 656ms/step - loss: 0.5287 - accuracy: 0.7513 - val_loss: 0.5636 - val_accuracy: 0.7429
# Fold 8 Results: Accuracy=74.29%, F1=0.73, Precision=0.74, Recall=0.74, Specificity=0.86, Kappa=0.43, ROC AUC=0.76
# Epoch 1/50
# 60/60 [==============================] - 38s 628ms/step - loss: 0.5397 - accuracy: 0.7376 - val_loss: 0.5189 - val_accuracy: 0.8000
# Epoch 2/50
# 60/60 [==============================] - 40s 660ms/step - loss: 0.5459 - accuracy: 0.7344 - val_loss: 0.5162 - val_accuracy: 0.8095
# Epoch 3/50
# 60/60 [==============================] - 41s 685ms/step - loss: 0.5360 - accuracy: 0.7524 - val_loss: 0.5091 - val_accuracy: 0.7429
# Epoch 4/50
# 60/60 [==============================] - 49s 823ms/step - loss: 0.5340 - accuracy: 0.7481 - val_loss: 0.5184 - val_accuracy: 0.8000
# Epoch 5/50
# 60/60 [==============================] - 47s 777ms/step - loss: 0.5404 - accuracy: 0.7333 - val_loss: 0.5079 - val_accuracy: 0.7619
# Epoch 6/50
# 60/60 [==============================] - 47s 786ms/step - loss: 0.5319 - accuracy: 0.7524 - val_loss: 0.5087 - val_accuracy: 0.7429
# Epoch 7/50
# 60/60 [==============================] - 46s 766ms/step - loss: 0.5272 - accuracy: 0.7503 - val_loss: 0.5004 - val_accuracy: 0.7524
# Epoch 10/50
# 60/60 [==============================] - 45s 746ms/step - loss: 0.5199 - accuracy: 0.7556 - val_loss: 0.4964 - val_accuracy: 0.7619
# Epoch 11/50
# 60/60 [==============================] - 41s 682ms/step - loss: 0.5171 - accuracy: 0.7577 - val_loss: 0.5003 - val_accuracy: 0.7714
# Epoch 12/50
# 60/60 [==============================] - 39s 648ms/step - loss: 0.5248 - accuracy: 0.7481 - val_loss: 0.4946 - val_accuracy: 0.8095
# Fold 10 Results: Accuracy=81.90%, F1=0.81, Precision=0.82, Recall=0.82, Specificity=0.92, Kappa=0.60, ROC AUC=0.83
# Mean and Std Dev of Performance Metrics for Spectrogram cqt:
# Fold                    5.500000
# Accuracy               74.285714
# F1 Score                0.717502
# Precision               0.719011
# Recall                  0.742857
# Specificity             0.904079
# Kappa                   0.399343
# ROC AUC                 0.758389
# Training Time (s)    8268.412686
# Testing Time (s)        8.033976
# dtype: float64
# Fold                     3.027650
# Accuracy                 6.089945
# F1 Score                 0.095653
# Precision                0.124575
# Recall                   0.060899
# Specificity              0.048605
# Kappa                    0.178139
# ROC AUC                  0.073145
# Training Time (s)    14912.607339
# Testing Time (s)         6.631222
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['cqt']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the MobileNetV2 model function
def build_mobilenetv2_model(input_shape, num_classes):
    base_model = tf.keras.applications.MobileNetV2(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_mobilenetv2_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: cqt
# Epoch 1/50
# 60/60 [==============================] - 18s 300ms/step - loss: 0.6517 - accuracy: 0.6307 - val_loss: 0.6646 - val_accuracy: 0.6571
# Epoch 2/50
# 60/60 [==============================] - 15s 250ms/step - loss: 0.5562 - accuracy: 0.7228 - val_loss: 0.6477 - val_accuracy: 0.6857
# Epoch 3/50
# 60/60 [==============================] - 15s 247ms/step - loss: 0.5046 - accuracy: 0.7746 - val_loss: 0.6301 - val_accuracy: 0.6952
# Epoch 4/50
# 60/60 [==============================] - 15s 248ms/step - loss: 0.4684 - accuracy: 0.8042 - val_loss: 0.6347 - val_accuracy: 0.7048
# Epoch 5/50
# 60/60 [==============================] - 15s 247ms/step - loss: 0.4336 - accuracy: 0.8265 - val_loss: 0.6189 - val_accuracy: 0.6952
# 60/60 [==============================] - 15s 251ms/step - loss: 0.2080 - accuracy: 0.9450 - val_loss: 0.3055 - val_accuracy: 0.8762
# Fold 2 Results: Accuracy=89.52%, F1=0.89, Precision=0.89, Recall=0.90, Specificity=0.92, Kappa=0.77, ROC AUC=0.97
# Epoch 1/50
# 60/60 [==============================] - 30s 505ms/step - loss: 0.2908 - accuracy: 0.8984 - val_loss: 0.2540 - val_accuracy: 0.9429
# Epoch 2/50
# 60/60 [==============================] - 17s 288ms/step - loss: 0.2577 - accuracy: 0.9153 - val_loss: 0.2652 - val_accuracy: 0.8952
# Epoch 3/50
# 60/60 [==============================] - 17s 283ms/step - loss: 0.2483 - accuracy: 0.9238 - val_loss: 0.2721 - val_accuracy: 0.9048
# Epoch 4/50
# 60/60 [==============================] - 18s 299ms/step - loss: 0.2229 - accuracy: 0.9386 - val_loss: 0.2619 - val_accuracy: 0.9429
# Epoch 5/50
# 60/60 [==============================] - 19s 311ms/step - loss: 0.2082 - accuracy: 0.9418 - val_loss: 0.2705 - val_accuracy: 0.9048
# Epoch 6/50
# 60/60 [==============================] - 17s 283ms/step - loss: 0.1950 - accuracy: 0.9545 - val_loss: 0.2575 - val_accuracy: 0.9143
# Fold 3 Results: Accuracy=94.29%, F1=0.94, Precision=0.94, Recall=0.94, Specificity=0.97, Kappa=0.88, ROC AUC=0.98
# Epoch 1/50
# 60/60 [==============================] - 19s 320ms/step - loss: 0.2736 - accuracy: 0.9079 - val_loss: 0.2171 - val_accuracy: 0.9048
# Epoch 2/50
# 60/60 [==============================] - 17s 280ms/step - loss: 0.2466 - accuracy: 0.9259 - val_loss: 0.2006 - val_accuracy: 0.9524
# Epoch 3/50
# 60/60 [==============================] - 17s 287ms/step - loss: 0.2246 - accuracy: 0.9429 - val_loss: 0.1994 - val_accuracy: 0.9524
# Epoch 4/50
# 60/60 [==============================] - 16s 273ms/step - loss: 0.2107 - accuracy: 0.9460 - val_loss: 0.2049 - val_accuracy: 0.9143
# Epoch 5/50
# 60/60 [==============================] - 17s 276ms/step - loss: 0.1936 - accuracy: 0.9545 - val_loss: 0.1960 - val_accuracy: 0.9524
# Epoch 6/50
# 60/60 [==============================] - 17s 277ms/step - loss: 0.1808 - accuracy: 0.9619 - val_loss: 0.1999 - val_accuracy: 0.9333
# Epoch 7/50
# 60/60 [==============================] - 17s 278ms/step - loss: 0.1660 - accuracy: 0.9630 - val_loss: 0.2044 - val_accuracy: 0.9143
# Epoch 8/50
# 60/60 [==============================] - 17s 277ms/step - loss: 0.1525 - accuracy: 0.9735 - val_loss: 0.2003 - val_accuracy: 0.9143
# Epoch 9/50
# 60/60 [==============================] - 17s 285ms/step - loss: 0.1416 - accuracy: 0.9767 - val_loss: 0.2038 - val_accuracy: 0.9238
# Epoch 10/50
# 60/60 [==============================] - 17s 277ms/step - loss: 0.1342 - accuracy: 0.9778 - val_loss: 0.2125 - val_accuracy: 0.9048
# Fold 4 Results: Accuracy=95.24%, F1=0.95, Precision=0.95, Recall=0.95, Specificity=0.94, Kappa=0.90, ROC AUC=0.99
# Fold 9 Results: Accuracy=100.00%, F1=1.00, Precision=1.00, Recall=1.00, Specificity=1.00, Kappa=1.00, ROC AUC=1.00
# Epoch 1/50
# 60/60 [==============================] - 25s 423ms/step - loss: 0.0770 - accuracy: 0.9937 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 2/50
# 60/60 [==============================] - 23s 376ms/step - loss: 0.0680 - accuracy: 0.9926 - val_loss: 0.0814 - val_accuracy: 0.9905
# Epoch 3/50
# 60/60 [==============================] - 23s 378ms/step - loss: 0.0551 - accuracy: 0.9958 - val_loss: 0.0716 - val_accuracy: 1.0000
# Epoch 4/50
# 60/60 [==============================] - 23s 381ms/step - loss: 0.0462 - accuracy: 0.9989 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 5/50
# 60/60 [==============================] - 22s 367ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9905
# Epoch 6/50
# 60/60 [==============================] - 24s 406ms/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9810
# Fold 10 Results: Accuracy=100.00%, F1=1.00, Precision=1.00, Recall=1.00, Specificity=1.00, Kappa=1.00, ROC AUC=1.00
# Mean and Std Dev of Performance Metrics for Spectrogram cqt:
# Fold                   5.500000
# Accuracy              94.095238
# F1 Score               0.940397
# Precision              0.940794
# Recall                 0.940952
# Specificity            0.960606
# Kappa                  0.871565
# ROC AUC                0.965540
# Training Time (s)    157.343502
# Testing Time (s)       4.661832
# dtype: float64
# Fold                  3.027650
# Accuracy              8.897955
# F1 Score              0.090379
# Precision             0.090934
# Recall                0.088980
# Specificity           0.061525
# Kappa                 0.195632
# ROC AUC               0.079828
# Training Time (s)    52.821098
# Testing Time (s)      0.726972
# dtype: float64

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score, cohen_kappa_score
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import time

# Define the base path for all data folders
data_dir = r'F:\PhD 2021-2024\Phd-IV Year\VIII\Voice MDVR\DATASET V\Cleaned_ReadTextCONVERTED'
spectrogram_folders = ['cqt']

# Function to load images and labels from a directory
def load_data_from_directory(base_path, label):
    img_data_list = []
    labels = []
    for img_file in os.listdir(base_path):
        img_path = os.path.join(base_path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            img_data_list.append(img)
            labels.append(label)
    return img_data_list, labels

# Define the VGG19 model function
def build_vgg19_model(input_shape, num_classes):
    base_model = tf.keras.applications.VGG19(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

# Process each spectrogram folder separately
for spectrogram in spectrogram_folders:
    print(f"Training model for spectrogram type: {spectrogram}")

    control_path = os.path.join(data_dir, spectrogram, 'HC')
    pathological_path = os.path.join(data_dir, spectrogram, 'PD')

    control_images, control_labels = load_data_from_directory(control_path, 0)
    pathological_images, pathological_labels = load_data_from_directory(pathological_path, 1)

    img_data_list = control_images + pathological_images
    labels = control_labels + pathological_labels

    img_data = np.array(img_data_list).astype('float32') / 255.0
    labels = np.array(labels)
    x, y = shuffle(img_data, labels, random_state=42)

    num_classes = 2
    input_shape = (128, 128, 3)
    model = build_vgg19_model(input_shape, num_classes)

    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_metrics = []
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_index, test_index) in enumerate(kfold.split(x, y), 1):
        X_train, X_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        y_train = to_categorical(y_train, num_classes)
        y_test = to_categorical(y_test, num_classes)

        model.compile(optimizer=Adam(learning_rate=0.0001, decay=0.0006), loss='binary_crossentropy', metrics=['accuracy'])
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        # Record training time
        start_train = time.time()
        history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1, callbacks=[early_stop])
        training_time = time.time() - start_train

        # Record testing time
        start_test = time.time()
        y_pred_prob = model.predict(X_test)
        testing_time = time.time() - start_test

        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)

        # Calculate metrics
        accuracy = np.mean(y_pred == y_true) * 100
        f1 = f1_score(y_true, y_pred, average='weighted')
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        kappa = cohen_kappa_score(y_true, y_pred)

        # Specificity calculation
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
        specificity = tn / (tn + fp)

        fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
        roc_auc = auc(fpr, tpr)
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(roc_auc)

        fold_metrics.append({
            "Fold": fold,
            "Accuracy": accuracy,
            "F1 Score": f1,
            "Precision": precision,
            "Recall": recall,
            "Specificity": specificity,
            "Kappa": kappa,
            "ROC AUC": roc_auc,
            "Training Time (s)": training_time,
            "Testing Time (s)": testing_time
        })

        print(f"Fold {fold} Results: Accuracy={accuracy:.2f}%, F1={f1:.2f}, Precision={precision:.2f}, Recall={recall:.2f}, Specificity={specificity:.2f}, Kappa={kappa:.2f}, ROC AUC={roc_auc:.2f}")
        
    # Plot ROC Curve with mean and std deviation
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    std_tpr = np.std(tprs, axis=0)

    plt.figure()
    plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {mean_auc:.2f} ± {std_auc:.2f})')
    plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr, color='grey', alpha=0.2, label='± 1 std. dev.')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {spectrogram} Spectrogram')
    plt.legend(loc="lower right")
    plt.show()

    # Display mean and std dev of other metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()

    print(f"\nMean and Std Dev of Performance Metrics for Spectrogram {spectrogram}:")
    print(mean_metrics)
    print(std_metrics)
# Out:
# Training model for spectrogram type: cqt
# KeyboardInterrupt

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
accuracy_updated = [
    [81.80, 77.45, 81.37, 100.00, 98.53],  # RF
    [89.71, 65.20, 63.24, 98.04, 74.50],   # KNN
    [70.10, 73.53, 71.57, 100.00, 100.00], # DT
    [83.82, 78.43, 81.37, 100.00, 100.00]  # Adaboost
]

# Simulated error margins for illustration purposes
error_updated = [
    [1.5, 1.0, 1.2, 0, 0.3],  # RF
    [1.0, 1.8, 1.5, 0.5, 0.6],  # KNN
    [1.8, 1.4, 1.6, 0, 0],  # DT
    [1.3, 1.1, 1.2, 0, 0]  # Adaboost
]

# Plotting setup
x = np.arange(len(feature_sets))  # Feature set indices
width = 0.2  # Width of the bars
colors = ['blue', 'orange', 'green', 'red']  # Colors for the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (model, color) in enumerate(zip(models, colors)):
    ax.bar(
        x + i * width, 
        accuracy_updated[i], 
        width, 
        yerr=error_updated[i], 
        label=model, 
        color=color, 
        capsize=5, 
        edgecolor='black', 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Feature Sets', fontsize=12)
ax.set_ylabel('Accuracy (%)', fontsize=12)
ax.set_title('Model Accuracy by Feature Set', fontsize=14)
ax.set_xticks(x + width * (len(models) - 1) / 2)
ax.set_xticklabels(feature_sets, fontsize=10)
ax.legend(title="Models", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
accuracy_updated = [
    [81.80, 77.45, 81.37, 100.00, 98.53],  # RF
    [89.71, 65.20, 63.24, 98.04, 74.50],   # KNN
    [70.10, 73.53, 71.57, 100.00, 100.00], # DT
    [83.82, 78.43, 81.37, 100.00, 100.00]  # Adaboost
]

# Simulated error margins for illustration purposes
error_updated = [
    [1.5, 1.0, 1.2, 0, 0.3],  # RF
    [1.0, 1.8, 1.5, 0.5, 0.6],  # KNN
    [1.8, 1.4, 1.6, 0, 0],  # DT
    [1.3, 1.1, 1.2, 0, 0]  # Adaboost
]

# Plotting setup
x = np.arange(len(models))  # Model indices
width = 0.15  # Width of the bars
colors = ['blue', 'orange', 'green', 'red']  # Colors for the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (feature_set, color) in enumerate(zip(feature_sets, colors)):
    ax.bar(
        x + i * width, 
        [accuracy_updated[j][i] for j in range(len(models))], 
        width, 
        yerr=[error_updated[j][i] for j in range(len(models))], 
        label=feature_set, 
        color=color, 
        capsize=5, 
        edgecolor='black', 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Accuracy (%)', fontsize=12)
ax.set_title('Model Accuracy by Feature Set', fontsize=14)
ax.set_xticks(x + width * (len(feature_sets) - 1) / 2)
ax.set_xticklabels(models, fontsize=10)
ax.legend(title="Feature Sets", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
accuracy = [
    [82.35, 72.55, 75.98, 100.00, 98.04],  # RF
    [89.22, 59.80, 64.71, 97.55, 73.04],   # KNN
    [75.00, 63.24, 57.84, 100.00, 99.02],  # DT
    [82.35, 73.53, 76.96, 100.00, 99.51]   # Adaboost
]


error_updated = [

    [2, 1.5, 1.8, 0, 0.5],  # RF

    [1.5, 2.2, 2, 0.5, 1],  # KNN

    [2, 2.5, 2.8, 0, 0.3],  # DT

    [1.8, 1.7, 1.5, 0, 0.2]  # Adaboost

]

# Plotting setup
x = np.arange(len(feature_sets))  # Feature set indices
width = 0.2  # Width of the bars
colors = ['blue', 'orange', 'green', 'red']  # Colors for the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (model, color) in enumerate(zip(models, colors)):
    ax.bar(
        x + i * width, 
        accuracy_updated[i], 
        width, 
        yerr=error_updated[i], 
        label=model, 
        color=color, 
        capsize=5, 
        edgecolor='black', 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Feature Sets', fontsize=12)
ax.set_ylabel('Accuracy (%)', fontsize=12)
ax.set_title('Model Accuracy by Feature Set for Multiclass (Normal, Mild, Moderate, Sever)', fontsize=14)
ax.set_xticks(x + width * (len(models) - 1) / 2)
ax.set_xticklabels(feature_sets, fontsize=10)
ax.legend(title="Models", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
accuracy_updated = [
    [82.35, 72.55, 75.98, 100.00, 98.04],  # RF
    [89.22, 59.80, 64.71, 97.55, 73.04],   # KNN
    [75.00, 63.24, 57.84, 100.00, 99.02],  # DT
    [82.35, 73.53, 76.96, 100.00, 99.51]   # Adaboost
]

error_updated = [
    [2, 1.5, 1.8, 0, 0.5],  # RF
    [1.5, 2.2, 2, 0.5, 1],  # KNN
    [2, 2.5, 2.8, 0, 0.3],  # DT
    [1.8, 1.7, 1.5, 0, 0.2]  # Adaboost
]

# Plotting setup
x = np.arange(len(models))  # Model indices
width = 0.15  # Width of the bars
colors = ['blue', 'orange', 'green', 'red']  # Colors for the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (feature_set, color) in enumerate(zip(feature_sets, colors)):
    ax.bar(
        x + i * width, 
        [accuracy_updated[j][i] for j in range(len(models))], 
        width, 
        yerr=[error_updated[j][i] for j in range(len(models))], 
        label=feature_set, 
        color=color, 
        capsize=5, 
        edgecolor='black', 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Accuracy (%)', fontsize=12)
ax.set_title('Model Accuracy by Feature Set for Multiclass (Normal, Mild, Moderate, Severe)', fontsize=14)
ax.set_xticks(x + width * (len(feature_sets) - 1) / 2)
ax.set_xticklabels(models, fontsize=10)
ax.legend(title="Feature Sets", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
testing_times = [
    [0.038, 0.122, 0.040, 0.072, 0.116],  # RF
    [0.007, 0.010, 0.004, 0.003, 0.017],  # KNN
    [0.014, 0.004, 0.004, 0.004, 0.002],  # DT
    [0.063, 0.069, 0.076, 0.002, 0.040]   # Adaboost
]

# Plotting setup
x = np.arange(len(models))  # Model indices
width = 0.15  # Width of the bars
colors = ['blue', 'orange', 'green', 'red']  # Colors for the bars

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (feature_set, color) in enumerate(zip(feature_sets, colors)):
    ax.bar(
        x + i * width, 
        [testing_times[j][i] for j in range(len(models))], 
        width, 
        label=feature_set, 
        color=color, 
        edgecolor='black', 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Testing Time (seconds)', fontsize=12)
ax.set_title('Testing Time by Feature Set for Different Models', fontsize=14)
ax.set_xticks(x + width * (len(feature_sets) - 1) / 2)
ax.set_xticklabels(models, fontsize=10)
ax.legend(title="Feature Sets", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
testing_times = [
    [0.038, 0.122, 0.040, 0.072, 0.116],  # RF
    [0.007, 0.010, 0.004, 0.003, 0.017],  # KNN
    [0.014, 0.004, 0.004, 0.004, 0.002],  # DT
    [0.063, 0.069, 0.076, 0.002, 0.040]   # Adaboost
]

# Plotting setup
x = np.arange(len(feature_sets))  # Feature set indices
colors = ['blue', 'orange', 'green', 'red']  # Line colors

# Create the line plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (model, color) in enumerate(zip(models, colors)):
    ax.plot(
        x, 
        testing_times[i], 
        label=model, 
        marker='o', 
        linestyle='-', 
        color=color, 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Feature Sets', fontsize=12)
ax.set_ylabel('Testing Time (seconds)', fontsize=12)
ax.set_title('Testing Time by Feature Set for Different Models', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(feature_sets, fontsize=10)
ax.legend(title="Models", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
models = ["RF", "KNN", "DT", "Adaboost"]
feature_sets = ["MFCC", "Spectrogram", "Spectral", "Voice_Quality", "All Combined"]
testing_times = [
    [0.037, 0.032, 0.046, 0.016, 0.032],  # RF
    [0.349, 0.001, 0.001, 0.020, 0.006],  # KNN
    [0.002, 0.003, 0.002, 0.824, 0.735],  # DT
    [0.770, 1.000, 0.995, 0.995, 0.824]   # Adaboost
]

# Plotting setup
x = np.arange(len(feature_sets))  # Feature set indices
colors = ['blue', 'orange', 'green', 'red']  # Line colors

# Create the line plot
fig, ax = plt.subplots(figsize=(12, 6))
for i, (model, color) in enumerate(zip(models, colors)):
    ax.plot(
        x, 
        testing_times[i], 
        label=model, 
        marker='o', 
        linestyle='-', 
        color=color, 
        alpha=0.9
    )

# Labels and formatting
ax.set_xlabel('Feature Sets', fontsize=12)
ax.set_ylabel('Testing Time (seconds)', fontsize=12)
ax.set_title('Testing Time by Feature Set for Different Models', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(feature_sets, fontsize=10)
ax.legend(title="Models", fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
